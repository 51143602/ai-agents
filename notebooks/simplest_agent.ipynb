# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition adive.
    You give a concise answers.
    """    
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Bananas are generally healthy as part of a balanced diet.
#
#     Key benefits:
#     - Rich in potassium, vitamin C, vitamin B6, and dietary fiber.
#     - Provide quick energy from natural sugars; unripe bananas have more resistant starch (prebiotic).
#     - Convenient, affordable, portable.
#
#     Things to consider:
#     - Moderate in calories and sugars (about 105 calories, ~14 g sugar for a medium banana).
#     - Diabetics or those watching sugars should portion accordingly.
#     - Some people may experience gas or bloating if sensitive to fiber or fructose.
#
#     Overall: a nutritious, convenient fruit—great in moderation.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are generally healthy.
#
# Key benefits:
# - Rich in potassium, vitamin B6, vitamin C, and fiber
# - Moderate calories (about 100 kcal for a medium banana)
# - Good quick energy source due to natural sugars
#
# Considerations:
# - Higher in sugar as they ripen; greener bananas have more resistant starch
# - Glycemic impact is moderate; people with diabetes should consider portion size
# - Limitations for kidney disease due to potassium content
#
# Pairs well with protein or fats for balanced meals.

# %% [markdown]
# _Good Job!_
