# %% [markdown]
# # Short-Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y 
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# 1) Bananas: 7/10 - Good nutrients (potassium, fiber, vitamins); natural sugars but balanced.
# 2) Lollipop: 2/10 - MostlyAdded sugar; little to no nutrients.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# I’m missing what X and Y are. Please provide the two foods you want to compare, or I can create a sample with apples plus two common foods (e.g., broccoli and almonds).

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?"
)
print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Nutrient-rich (potassium, fiber, vitamins); natural sugars.
# 2) Lollipop: 2/10 - Mostly refined sugar; no meaningful nutrients.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(result.final_output)
# Out:
# Here’s a default comparison including apples:
#
# 1) Oats: 9/10 - High fiber, steady energy; low fat; versatile. Watch for added sugar if flavored.
# 2) Apples: 8/10 - Good fiber and polyphenols; low calories; mostly natural sugars.
# 3) Oranges: 8/10 - Vitamin C-rich; fiber; hydrating; natural sugars.
# 4) Yogurt (plain): 7/10 - Protein and calcium; low sugar if plain; watch portion size if flavored.
# 5) Bananas: 7/10 - Potassium and quick energy; higher natural sugar.
#
# If you’d like different foods or a specific focus (e.g., low sugar, high protein), tell me and I’ll adjust.
