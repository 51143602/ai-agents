# %% [markdown]
# # MCP

# %%
import os

import chromadb
import dotenv
from agents import Agent, Runner, function_tool, trace
from agents.mcp import MCPServerStreamableHttp

dotenv.load_dotenv()
# Out:
# True

# %% [markdown]
# Let's set up our RAG database connection:

# %%
chroma_client = chromadb.PersistentClient(path="../chroma")
nutrition_db = chroma_client.get_collection(name="nutrition_db")

# %%
# This is the same code as in the rag.ipynb notebook


@function_tool
def calorie_lookup_tool(query: str, max_results: int = 3) -> str:
    """
    Tool function for a RAG database to look up calorie information for specific food items, but not for meals.

    Args:
        query: The food item to look up.
        max_results: The maximum number of results to return.

    Returns:
        A string containing the nutrition information.
    """

    results = nutrition_db.query(query_texts=[query], n_results=max_results)

    if not results["documents"][0]:
        return f"No nutrition information found for: {query}"

    # Format results for the agent
    formatted_results = []
    for i, doc in enumerate(results["documents"][0]):
        metadata = results["metadatas"][0][i]
        food_item = metadata["food_item"].title()
        calories = metadata["calories_per_100g"]
        category = metadata["food_category"].title()

        formatted_results.append(
            f"{food_item} ({category}): {calories} calories per 100g"
        )

    return "Nutrition Information:\n" + "\n".join(formatted_results)

# %% [markdown]
# Integrate EXA Search as an MCP:

# %%
# Exa Search MCP code comes here:
exa_search_mcp = MCPServerStreamableHttp(
    name="Exa Search MCP",
    params={
        "url": f"https://mcp.exa.ai/mcp/mcp?exaApiKey={os.environ.get('EXA_API_KEY')}",
        "timeout": 30,
    },
    client_session_timeout_seconds=30,
    cache_tools_list=True,
    max_retry_attempts=1,
)

await exa_search_mcp.connect()

calorie_agent_with_search = Agent(
    name="Nutrition Assistant",
    instructions="""
    * You are a helpful nutrition assistant giving out calorie information.
    * You give concise answers.
    * You follow this workflow:
        0) First, use the calorie_lookup_tool to get the calorie information of the ingredients. But only use the result if it's explicitly for the food requested in the query.
        1) If you couldn't find the exact match for the food or you need to look up the ingredients, search the EXA web to figure out the exact ingredients of the meal.
        Even if you have the calories in the web search response, you should still use the calorie_lookup_tool to get the calorie
        information of the ingredients to make sure the information you provide is consistent.
        2) Then, if necessary, use the calorie_lookup_tool to get the calorie information of the ingredients.
    * Even if you know the recipe of the meal, always use Exa Search to find the exact recipe and ingredients.
    * Once you know the ingredients, use the calorie_lookup_tool to get the calorie information of the individual ingredients.
    * If the query is about the meal, in your final output give a list of ingredients with their quantities and calories for a single serving. Also display the total calories.
    * Don't use the calorie_lookup_tool more than 10 times.
    """,
    tools=(calorie_lookup_tool),
    mcp_servers=(exa_search_mcp)
)
# Out:
# Error initializing MCP server: Session terminated
# ---------------------------------------------------------------------------
# McpError                                  Traceback (most recent call last)
# Cell In[22], line 13
#       1 # Exa Search MCP code comes here:
#       2 exa_search_mcp = MCPServerStreamableHttp(
#       3     name="Exa Search MCP",
#       4     params={
#    (...)     10     max_retry_attempts=1,
#      11 )
# ---> 13 await exa_search_mcp.connect()
#      15 calorie_agent_with_search = Agent(
#      16     name="Nutrition Assistant",
#      17     instructions="""
#    (...)     32     mcp_servers=(exa_search_mcp)
#      33 )
#
# File ~/.local/lib/python3.13/site-packages/agents/mcp/server.py:277, in _MCPServerWithClientSession.connect(self)
#     266 read, write, *_ = transport
#     268 session = await self.exit_stack.enter_async_context(
#     269     ClientSession(
#     270         read,
#    (...)    275     )
#     276 )
# --> 277 server_result = await session.initialize()
#     278 self.server_initialize_result = server_result
#     279 self.session = session
#
# File ~/.local/lib/python3.13/site-packages/mcp/client/session.py:151, in ClientSession.initialize(self)
#     139 elicitation = (
#     140     types.ElicitationCapability() if self._elicitation_callback is not _default_elicitation_callback else None
#     141 )
#     142 roots = (
#     143     # TODO: Should this be based on whether we
#     144     # _will_ send notifications, or only whether
#    (...)    148     else None
#     149 )
# --> 151 result = await self.send_request(
#     152     types.ClientRequest(
#     153         types.InitializeRequest(
#     154             params=types.InitializeRequestParams(
#     155                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     156                 capabilities=types.ClientCapabilities(
#     157                     sampling=sampling,
#     158                     elicitation=elicitation,
#     159                     experimental=None,
#     160                     roots=roots,
#     161                 ),
#     162                 clientInfo=self._client_info,
#     163             ),
#     164         )
#     165     ),
#     166     types.InitializeResult,
#     167 )
#     169 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     170     raise RuntimeError(f"Unsupported protocol version from the server: {result.protocolVersion}")
#
# File ~/.local/lib/python3.13/site-packages/mcp/shared/session.py:286, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     274     raise McpError(
#     275         ErrorData(
#     276             code=httpx.codes.REQUEST_TIMEOUT,
#    (...)    282         )
#     283     )
#     285 if isinstance(response_or_error, JSONRPCError):
# --> 286     raise McpError(response_or_error.error)
#     287 else:
#     288     return result_type.model_validate(response_or_error.result)
#
# McpError: Session terminated

# %% [markdown]
# Reference query - shouldn't use ExaSearch:

# %%
with trace("Nutrition Assistant with MCP - Only uses calorie_lookup_tool"):
    result = await Runner.run(
        calorie_agent_with_search,
        "How many calories are in total in a banana and an apple? Also give calories per 100g",
    )
    print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 with trace("Nutrition Assistant with MCP - Only uses calorie_lookup_tool"):
#       2     result = await Runner.run(
# ----> 3         calorie_agent_with_search,
#       4         "How many calories are in total in a banana and an apple? Also give calories per 100g",
#       5     )
#       6     print(result)
#
# NameError: name 'calorie_agent_with_search' is not defined

# %%
with trace("Nutrition Assistant with MCP "):
    result = await Runner.run(
        calorie_agent_with_search, "How many calories are in an english breakfast?"
    )
    print(result.final_output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 with trace("Nutrition Assistant with MCP "):
#       2     result = await Runner.run(
# ----> 3         calorie_agent_with_search, "How many calories are in an english breakfast?"
#       4     )
#       5     print(result.final_output)
#
# NameError: name 'calorie_agent_with_search' is not defined
